# %%
import torch
import matplotlib.pyplot as plt

# %%
from unet.model import UNet
from utils.constants import BATCH_SIZE, IMAGE_SIZE
from torchinfo import summary
import os

device = 'cuda' if torch.cuda.is_available() else 'cpu'

model, model_name = UNet(), "UNet_carvana.pth"
path = os.path.join("..", 'models', model_name)
model.load_state_dict(torch.load(path, weights_only=True))
model.to(device)
model.eval()
summary(model, input_size=(BATCH_SIZE, 3, *IMAGE_SIZE))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# UNet                                     [8, 1, 256, 256]          --
# ├─ModuleList: 1-1                        --                        --
# │    └─DoubleConv: 2-1                   [8, 64, 256, 256]         --
# │    │    └─Sequential: 3-1              [8, 64, 256, 256]         38,976
# │    └─DoubleConv: 2-2                   [8, 128, 128, 128]        --
# │    │    └─Sequential: 3-2              [8, 128, 128, 128]        221,952
# │    └─DoubleConv: 2-3                   [8, 256, 64, 64]          --
# │    │    └─Sequential: 3-3              [8, 256, 64, 64]          886,272
# │    └─DoubleConv: 2-4                   [8, 512, 32, 32]          --
# │    │    └─Sequential: 3-4              [8, 512, 32, 32]          3,542,016
# ├─DoubleConv: 1-2                        [8, 1024, 16, 16]         --
# │    └─Sequential: 2-5                   [8, 1024, 16, 16]         --
# │    │    └─Conv2d: 3-5                  [8, 1024, 16, 16]         4,719,616
# │    │    └─BatchNorm2d: 3-6             [8, 1024, 16, 16]         2,048
# │    │    └─GELU: 3-7                    [8, 1024, 16, 16]         --
# │    │    └─Conv2d: 3-8                  [8, 1024, 16, 16]         9,438,208
# │    │    └─BatchNorm2d: 3-9             [8, 1024, 16, 16]         2,048
# │    │    └─GELU: 3-10                   [8, 1024, 16, 16]         --
# │    │    └─Dropout2d: 3-11              [8, 1024, 16, 16]         --
# ├─ModuleList: 1-3                        --                        --
# │    └─ConvTranspose2d: 2-6              [8, 512, 32, 32]          2,097,664
# │    └─DoubleConv: 2-7                   [8, 512, 32, 32]          --
# │    │    └─Sequential: 3-12             [8, 512, 32, 32]          7,080,960
# │    └─ConvTranspose2d: 2-8              [8, 256, 64, 64]          524,544
# │    └─DoubleConv: 2-9                   [8, 256, 64, 64]          --
# │    │    └─Sequential: 3-13             [8, 256, 64, 64]          1,771,008
# │    └─ConvTranspose2d: 2-10             [8, 128, 128, 128]        131,200
# │    └─DoubleConv: 2-11                  [8, 128, 128, 128]        --
# │    │    └─Sequential: 3-14             [8, 128, 128, 128]        443,136
# │    └─ConvTranspose2d: 2-12             [8, 64, 256, 256]         32,832
# │    └─DoubleConv: 2-13                  [8, 64, 256, 256]         --
# │    │    └─Sequential: 3-15             [8, 64, 256, 256]         110,976
# ├─Conv2d: 1-4                            [8, 1, 256, 256]          65
# ==========================================================================================
# Total params: 31,043,521
# Trainable params: 31,043,521
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 437.20
# ==========================================================================================
# Input size (MB): 6.29
# Forward/backward pass size (MB): 4601.15
# Params size (MB): 124.17
# Estimated Total Size (MB): 4731.62
# ==========================================================================================

# %%
from dataset.transforms import get_train_transforms
from torch.utils.data import DataLoader
from dataset.carvana_dataset import CarvanaDataset

dataset = CarvanaDataset('../data', True, transforms=get_train_transforms())
dataloader = DataLoader(dataset, batch_size=4, shuffle=True, num_workers=2, pin_memory=True)
imgs, masks = next(iter(dataloader))
imgs, masks = imgs.to(device), masks.to(device)

# %%
fig, axs = plt.subplots(4, 4, figsize=(12, 12))

fig.suptitle('UNet Model Demo', fontsize=16)

for i in range(4):
    pred_dict = model.predict(imgs[i])    
    pred = pred_dict['pred']
    img = pred_dict['img']
    logits = pred_dict['logits']
    true_mask = masks[i].cpu().numpy().transpose(1, 2, 0)
    
    axs[0, i].imshow(img)
    axs[0, i].axis('off')
    axs[0, i].set_title('Image')
    
    axs[1, i].imshow(pred)
    axs[1, i].axis('off')
    axs[1, i].set_title('Pred mask')
    
    axs[2, i].imshow(true_mask)
    axs[2, i].axis('off')
    axs[2, i].set_title('True Mask')
    
    axs[3, i].imshow(logits)
    axs[3, i].axis('off')
    axs[3, i].set_title('Logits')
    
plt.tight_layout()
plt.show()
